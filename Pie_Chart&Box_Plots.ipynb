# %% [markdown]
# ## *Preparing Data for visualization* <a id="4"></a>
#
#     Preparation is same. For any doubt see the Line_plot for more better understanding if seeing dataset for first time.

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
dt = pd.read_csv('cities_r2.csv')
print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
dt.head()
# tip: You can specify the number of rows you'd like to see as follows: df_can.head(10)
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
# name_of_city                      493 non-null object
# state_code                        493 non-null int64
# state_name                        493 non-null object
# dist_code                         493 non-null int64
# population_total                  493 non-null int64
# population_male                   493 non-null int64
# population_female                 493 non-null int64
# 0-6_population_total              493 non-null int64
# 0-6_population_male               493 non-null int64
# 0-6_population_female             493 non-null int64
# literates_total                   493 non-null int64
# literates_male                    493 non-null int64
# literates_female                  493 non-null int64
# sex_ratio                         493 non-null int64
# child_sex_ratio                   493 non-null int64
# effective_literacy_rate_total     493 non-null float64
# ...

# %%
dt.columns.tolist()
dt.index.tolist()

print (type(dt.columns.tolist()))
print (type(dt.index.tolist()))
# Out:
# <class 'list'>
# <class 'list'>

# %%
# in pandas axis=0 represents rows (default) and axis=1 represents columns.
dt.drop(['state_code', 'dist_code', 'location'], axis=1, inplace=True)
dt.head(2)
# Out:
#   name_of_city   state_name  population_total  population_male  \
# 0      Abohar        PUNJAB            145238            76840
# 1    Achalpur   MAHARASHTRA            112293            58256
#
#    population_female  0-6_population_total  0-6_population_male  \
# 0              68398                 15870                 8587
# 1              54037                 11810                 6186
#
#    0-6_population_female  literates_total  literates_male  literates_female  \
# 0                   7283           103319           58347             44972
# 1                   5624            92433           49347             43086
#
#    sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 0        890              848                          79.86
# 1        928              909                          91.99
#
#    effective_literacy_rate_male  effective_literacy_rate_female  \
# 0                         85.49                           73.59
# ...

# %%
dt.isnull().sum()
# Out:
# name_of_city                      0
# state_name                        0
# population_total                  0
# population_male                   0
# population_female                 0
# 0-6_population_total              0
# 0-6_population_male               0
# 0-6_population_female             0
# literates_total                   0
# literates_male                    0
# literates_female                  0
# sex_ratio                         0
# child_sex_ratio                   0
# effective_literacy_rate_total     0
# effective_literacy_rate_male      0
# effective_literacy_rate_female    0
# total_graduates                   0
# male_graduates                    0
# female_graduates                  0
# dtype: int64

# %%
dt.set_index('state_name', inplace=True)
# tip: The opposite of set is reset. So to reset the index, we can use df_can.reset_index()
dt.head(2)
# Out:
#             name_of_city  population_total  population_male  \
# state_name
# PUNJAB           Abohar             145238            76840
# MAHARASHTRA    Achalpur             112293            58256
#
#              population_female  0-6_population_total  0-6_population_male  \
# state_name
# PUNJAB                   68398                 15870                 8587
# MAHARASHTRA              54037                 11810                 6186
#
#              0-6_population_female  literates_total  literates_male  \
# state_name
# PUNJAB                        7283           103319           58347
# MAHARASHTRA                   5624            92433           49347
#
#              literates_female  sex_ratio  child_sex_ratio  \
# state_name
# PUNJAB                  44972        890              848
# MAHARASHTRA             43086        928              909
#
#              effective_literacy_rate_total  effective_literacy_rate_male  \
# state_name
# ...

# %%
dt.describe()
# Out:
#        population_total  population_male  population_female  \
# count      4.930000e+02     4.930000e+02       4.930000e+02
# mean       4.481124e+05     2.343468e+05       2.137656e+05
# std        1.033228e+06     5.487786e+05       4.848622e+05
# min        1.000360e+05     5.020100e+04       4.512600e+04
# 25%        1.261420e+05     6.638400e+04       6.041100e+04
# 50%        1.841330e+05     9.665500e+04       8.776800e+04
# 75%        3.490330e+05     1.750550e+05       1.700260e+05
# max        1.247845e+07     6.736815e+06       5.741632e+06
#
#        0-6_population_total  0-6_population_male  0-6_population_female  \
# count          4.930000e+02           493.000000             493.000000
# mean           4.709285e+04         24849.527383           22243.320487
# std            1.050279e+05         55535.310272           49523.241379
# min            6.547000e+03          3406.000000            3107.000000
# ...

# %% [markdown]
# Import `Matplotlib`.

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.0.3

# %% [markdown]
# # Pie Charts <a id="6"></a>
#
# A `pie chart` is a circualr graphic that displays numeric proportions by dividing a circle (or pie) into proportional slices. You are most likely already familiar with pie charts as it is widely used in business and media. We can create pie charts in Matplotlib by passing in the `kind=pie` keyword.
#
# Let's use a pie chart to explore the proportion (percentage) of population of female literates grouped by States for visualising

# %% [markdown]
# Step 1: Gather data.
#
# We will use *pandas* `groupby` method to summarize the immigration data by `State`. The general process of `groupby` involves the following steps:
#
# 1. **Split:** Splitting the data into groups based on some criteria.
# 2. **Apply:** Applying a function to each group independently:
#        .sum()
#        .count()
#        .mean()
#        .std()
#        .aggregate()
#        .apply()
#        .etc..
# 3. **Combine:** Combining the results into a data structure.

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Images/Mod3Fig4SplitApplyCombine.png" height=400 align="center">

# %%
# group district by State and apply sum() function 
lis = dt.groupby('state_name', axis=0).sum()

# note: the output of the groupby method is a `groupby' object
lis.head()
# Out:
#                            population_total  population_male  \
# state_name
# ANDAMAN & NICOBAR ISLANDS            100608            53247
# ANDHRA PRADESH                     18171615          9192368
# ASSAM                               1391154           720132
# BIHAR                               6714516          3558722
# CHANDIGARH                           960787           525226
#
#                            population_female  0-6_population_total  \
# state_name
# ANDAMAN & NICOBAR ISLANDS              47361                  9358
# ANDHRA PRADESH                       8979247               1776846
# ASSAM                                 671022                125523
# BIHAR                                3155794                881486
# CHANDIGARH                            435561                104192
#
#                            0-6_population_male  0-6_population_female  \
# state_name
# ANDAMAN & NICOBAR ISLANDS                 4852                   4506
# ...

# %% [markdown]
# Step 2: Plot the data. We will pass in `kind = 'pie'` keyword, along with the following additional parameters:
# - `autopct` -  is a string or function used to label the wedges with their numeric value. The label will be placed inside the wedge. If it is a format string, the label will be `fmt%pct`.
# - `startangle` - rotates the start of the pie chart by angle degrees counterclockwise from the x-axis.
# - `shadow` - Draws a shadow beneath the pie (to give a 3D feel).

# %%
lis.sort_values(by = 'literates_female', ascending=False, axis=0, inplace=True) #sorting to get the top values
top = lis.head(5)
top['literates_female']
# Out:
# state_name
# MAHARASHTRA       13719511
# UTTAR PRADESH      7810410
# WEST BENGAL        6782848
# ANDHRA PRADESH     6285081
# GUJARAT            6233457
# Name: literates_female, dtype: int64

# %%
# autopct create %, start angle represent starting point
top['literates_female'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Female Literates in Top 5 states')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %% [markdown]
# **Female Literates in Least 5 states**

# %%
les = lis.tail(5)
les['literates_female']
# Out:
# state_name
# MANIPUR                      108452
# HIMACHAL PRADESH              65313
# MEGHALAYA                     59893
# NAGALAND                      44042
# ANDAMAN & NICOBAR ISLANDS     37000
# Name: literates_female, dtype: int64

# %%
# autopct create %, start angle represent starting point
les['literates_female'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Female Literates in Least 5 states')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %% [markdown]
# The above visual is not very clear, the numbers and text overlap in some instances. Let's make a few modifications to improve the visuals:
#
# * Remove the text labels on the pie chart by passing in `legend` and add it as a seperate legend using `plt.legend()`.
# * Push out the percentages to sit just outside the pie chart by passing in `pctdistance` parameter.
# * Pass in a custom set of colors for continents by passing in `colors` parameter.
# * **Explode** the pie chart to emphasize the low values by pasing in `explode` parameter.

# %% [markdown]
# **Now let us female graduates in different states**

# %%
fm = lis
fm = fm['female_graduates'].head(6)
fm
# Out:
# state_name
# MAHARASHTRA       2357917
# UTTAR PRADESH     1601432
# WEST BENGAL       1107147
# ANDHRA PRADESH    1083014
# GUJARAT            863607
# KARNATAKA         1054546
# Name: female_graduates, dtype: int64

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.

fm.plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 States
                            )

# scale the title up by 12% to match pctdistance
plt.title('The list of female graduates from different States', y=1.12) 

plt.axis('equal') 

# add legend
plt.legend(labels=fm.index, loc='upper left') 

plt.show()

# %% [markdown]
# # Box Plots <a id="8"></a>
#
# A `box plot` is a way of statistically representing the *distribution* of the data through five main dimensions:
#
# - **Minimun:** Smallest number in the dataset.
# - **First quartile:** Middle number between the `minimum` and the `median`.
# - **Second quartile (Median):** Middle number of the (sorted) dataset.
# - **Third quartile:** Middle number between `median` and `maximum`.
# - **Maximum:** Highest number in the dataset.

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Images/boxplot_complete.png" width=440, align="center">

# %% [markdown]
# To make a `box plot`, we can use `kind=box` in `plot` method invoked on a *pandas* series or dataframe.
#
# Let's plot the box plot for the Delhi population.

# %%
# group district by State and apply sum() function 
#lis = dt.groupby('state_name', axis=0).sum()

dt = pd.read_csv('cities_r2.csv')
dt.drop(['dist_code', 'location'], axis=1, inplace=True)
dh = dt.set_index('state_code')
dh = dh.groupby('state_code', axis=0).sum()

# note: the output of the groupby method is a `groupby' object
dh = dh.loc[:,['population_total']]
dh.sort_values(by = 'state_code', ascending=True, axis=0, inplace=True) #sorting to get the top values

#dh = dh.transpose()
dh
# Out:
#             population_total
# state_code
# 1                    1804987
# 2                     169758
# 3                    5821876
# 4                     960787
# 5                    1340397
# 6                    5952223
# 7                   13481997
# 8                   10443016
# 9                   25302925
# 10                   6714516
# 13                    123777
# 14                    264986
# 15                    291822
# 16                    399688
# 17                    143007
# 18                   1391154
# 19                  18063509
# 20                   4278259
# 21                   3003234
# 22                   3137918
# 23                  11023091
# 24                  17835049
# 27                  37722136
# 28                  18171615
# 29                  15799896
# 32                   2755973
# 33                  13879395
# 34                    541801
# 35                    100608

# %%
dh.plot(kind='box', figsize=(8, 6))

plt.title('India')
plt.ylabel('Box plot of Different State Population')

plt.show()
